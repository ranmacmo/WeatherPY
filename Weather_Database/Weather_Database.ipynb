# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 749

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | chara
# Processing Record 11 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 1 | gayny
# Processing Record 13 of Set 1 | belyy yar
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | uvat
# Processing Record 16 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 1 | thyboron
# Processing Record 18 of Set 1 | port hedland
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | varhaug
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | talnakh
# Processing Record 24 of Set 1 | nchelenge
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | ancud
# Processing Record 27 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 1 | surt
# Processing Record 29 of Set 1 | requena
# Processing Record 30 of Set 1 | ashland
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | triesenberg
# Processing Record 34 of Set 1 | manadhoo
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | weligama
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | berdigestyakh
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | fairlie
# Processing Record 44 of Set 1 | oktyabrskoye
# Processing Record 45 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 1 | najran
# Processing Record 47 of Set 1 | nishihara
# Processing Record 48 of Set 1 | victor harbor
# Processing Record 49 of Set 1 | hualmay
# Processing Record 50 of Set 1 | mezohegyes
# Processing Record 1 of Set 2 | souillac
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | coihaique
# Processing Record 4 of Set 2 | pleshanovo
# Processing Record 5 of Set 2 | riviere-au-renard
# Processing Record 6 of Set 2 | mecca
# Processing Record 7 of Set 2 | komsomolskiy
# Processing Record 8 of Set 2 | agadez
# Processing Record 9 of Set 2 | talara
# Processing Record 10 of Set 2 | campbell river
# Processing Record 11 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 2 | suraabad
# Processing Record 13 of Set 2 | ulladulla
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | yarmouth
# Processing Record 16 of Set 2 | toftir
# City not found. Skipping...
# Processing Record 17 of Set 2 | salvador
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | cayenne
# Processing Record 21 of Set 2 | port hawkesbury
# Processing Record 22 of Set 2 | adrar
# Processing Record 23 of Set 2 | tuatapere
# Processing Record 24 of Set 2 | ingham
# Processing Record 25 of Set 2 | ebebiyin
# Processing Record 26 of Set 2 | tokmak
# Processing Record 27 of Set 2 | nevyansk
# Processing Record 28 of Set 2 | necochea
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | puerto del rosario
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | chokurdakh
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | ketchikan
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | castro
# Processing Record 37 of Set 2 | san carlos de bariloche
# Processing Record 38 of Set 2 | teya
# Processing Record 39 of Set 2 | codrington
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | sanchor
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | oranjemund
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | nanortalik
# Processing Record 47 of Set 2 | vila velha
# Processing Record 48 of Set 2 | husavik
# Processing Record 49 of Set 2 | port elizabeth
# Processing Record 50 of Set 2 | chifeng
# Processing Record 1 of Set 3 | dongying
# Processing Record 2 of Set 3 | tarakan
# Processing Record 3 of Set 3 | qurayyat
# Processing Record 4 of Set 3 | itororo
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | camacha
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | asau
# Processing Record 9 of Set 3 | faanui
# Processing Record 10 of Set 3 | katsuura
# Processing Record 11 of Set 3 | leningradskiy
# Processing Record 12 of Set 3 | punta arenas
# Processing Record 13 of Set 3 | villazon
# Processing Record 14 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 3 | ust-maya
# Processing Record 16 of Set 3 | new norfolk
# Processing Record 17 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 3 | nikolskoye
# Processing Record 19 of Set 3 | marawi
# Processing Record 20 of Set 3 | wa
# City not found. Skipping...
# Processing Record 21 of Set 3 | gonbad-e qabus
# Processing Record 22 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 3 | shingu
# Processing Record 24 of Set 3 | sistranda
# Processing Record 25 of Set 3 | carnarvon
# Processing Record 26 of Set 3 | dingle
# Processing Record 27 of Set 3 | busselton
# Processing Record 28 of Set 3 | kaitangata
# Processing Record 29 of Set 3 | paucartambo
# City not found. Skipping...
# Processing Record 30 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 3 | ribeira grande
# Processing Record 32 of Set 3 | port hardy
# Processing Record 33 of Set 3 | svetlogorsk
# Processing Record 34 of Set 3 | vanimo
# Processing Record 35 of Set 3 | hovd
# Processing Record 36 of Set 3 | port-gentil
# Processing Record 37 of Set 3 | ventosa
# Processing Record 38 of Set 3 | cabo san lucas
# Processing Record 39 of Set 3 | lompoc
# Processing Record 40 of Set 3 | port alfred
# Processing Record 41 of Set 3 | asyut
# Processing Record 42 of Set 3 | contramaestre
# Processing Record 43 of Set 3 | chuy
# Processing Record 44 of Set 3 | macapa
# Processing Record 45 of Set 3 | santiago de cao
# Processing Record 46 of Set 3 | krasnoselkup
# Processing Record 47 of Set 3 | takoradi
# Processing Record 48 of Set 3 | payo
# Processing Record 49 of Set 3 | kungurtug
# Processing Record 50 of Set 3 | luderitz
# Processing Record 1 of Set 4 | okhotsk
# Processing Record 2 of Set 4 | barrow
# Processing Record 3 of Set 4 | borodino
# Processing Record 4 of Set 4 | marang
# Processing Record 5 of Set 4 | brae
# Processing Record 6 of Set 4 | adre
# Processing Record 7 of Set 4 | hirara
# Processing Record 8 of Set 4 | dano
# Processing Record 9 of Set 4 | jackson
# Processing Record 10 of Set 4 | cururupu
# Processing Record 11 of Set 4 | iranshahr
# Processing Record 12 of Set 4 | tasiilaq
# Processing Record 13 of Set 4 | kodinsk
# Processing Record 14 of Set 4 | isla aguada
# Processing Record 15 of Set 4 | cape town
# Processing Record 16 of Set 4 | beringovskiy
# Processing Record 17 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 4 | atambua
# Processing Record 19 of Set 4 | bondo
# Processing Record 20 of Set 4 | greenville
# Processing Record 21 of Set 4 | wasilla
# Processing Record 22 of Set 4 | kavieng
# Processing Record 23 of Set 4 | bulaevo
# Processing Record 24 of Set 4 | sortavala
# Processing Record 25 of Set 4 | turkmenabat
# Processing Record 26 of Set 4 | menongue
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | bulungu
# Processing Record 29 of Set 4 | moyale
# Processing Record 30 of Set 4 | abonnema
# Processing Record 31 of Set 4 | saldanha
# Processing Record 32 of Set 4 | darnah
# Processing Record 33 of Set 4 | beian
# Processing Record 34 of Set 4 | dunedin
# Processing Record 35 of Set 4 | provideniya
# Processing Record 36 of Set 4 | codaesti
# Processing Record 37 of Set 4 | sao filipe
# Processing Record 38 of Set 4 | broken hill
# Processing Record 39 of Set 4 | enshi
# Processing Record 40 of Set 4 | galveston
# Processing Record 41 of Set 4 | westport
# Processing Record 42 of Set 4 | paka
# Processing Record 43 of Set 4 | presidencia roque saenz pena
# Processing Record 44 of Set 4 | yulara
# Processing Record 45 of Set 4 | butaritari
# Processing Record 46 of Set 4 | panama city
# Processing Record 47 of Set 4 | vardo
# Processing Record 48 of Set 4 | grand-lahou
# Processing Record 49 of Set 4 | khuzdar
# Processing Record 50 of Set 4 | hithadhoo
# Processing Record 1 of Set 5 | mabai
# Processing Record 2 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 5 | fort nelson
# Processing Record 4 of Set 5 | kapoeta
# Processing Record 5 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 6 of Set 5 | vestmannaeyjar
# Processing Record 7 of Set 5 | labuhan
# Processing Record 8 of Set 5 | gagnoa
# Processing Record 9 of Set 5 | linxia
# Processing Record 10 of Set 5 | egvekinot
# Processing Record 11 of Set 5 | bonavista
# Processing Record 12 of Set 5 | clyde river
# Processing Record 13 of Set 5 | rocha
# Processing Record 14 of Set 5 | antalaha
# Processing Record 15 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 5 | mitsamiouli
# Processing Record 17 of Set 5 | texcoco
# Processing Record 18 of Set 5 | thinadhoo
# Processing Record 19 of Set 5 | iqaluit
# Processing Record 20 of Set 5 | denpasar
# Processing Record 21 of Set 5 | berlevag
# Processing Record 22 of Set 5 | huarmey
# Processing Record 23 of Set 5 | sur
# Processing Record 24 of Set 5 | saint-augustin
# Processing Record 25 of Set 5 | mandalgovi
# Processing Record 26 of Set 5 | dibaya
# City not found. Skipping...
# Processing Record 27 of Set 5 | khatanga
# Processing Record 28 of Set 5 | nome
# Processing Record 29 of Set 5 | sosua
# Processing Record 30 of Set 5 | aklavik
# Processing Record 31 of Set 5 | aksarka
# Processing Record 32 of Set 5 | salina cruz
# Processing Record 33 of Set 5 | kisesa
# Processing Record 34 of Set 5 | buala
# Processing Record 35 of Set 5 | constitucion
# Processing Record 36 of Set 5 | wattegama
# Processing Record 37 of Set 5 | jizan
# Processing Record 38 of Set 5 | bilma
# Processing Record 39 of Set 5 | porto santo
# Processing Record 40 of Set 5 | kruisfontein
# Processing Record 41 of Set 5 | fukue
# Processing Record 42 of Set 5 | pacifica
# Processing Record 43 of Set 5 | blonie
# Processing Record 44 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 5 | fukuma
# Processing Record 46 of Set 5 | lavrentiya
# Processing Record 47 of Set 5 | konya
# Processing Record 48 of Set 5 | bismarck
# Processing Record 49 of Set 5 | alexandria
# Processing Record 50 of Set 5 | beloha
# Processing Record 1 of Set 6 | jiayuguan
# Processing Record 2 of Set 6 | flinders
# Processing Record 3 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 6 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 5 of Set 6 | itaituba
# Processing Record 6 of Set 6 | salinopolis
# Processing Record 7 of Set 6 | quatre cocos
# Processing Record 8 of Set 6 | kavaratti
# Processing Record 9 of Set 6 | bambous virieux
# Processing Record 10 of Set 6 | bronnoysund
# Processing Record 11 of Set 6 | narsaq
# Processing Record 12 of Set 6 | zilair
# Processing Record 13 of Set 6 | bengkulu
# Processing Record 14 of Set 6 | padre paraiso
# Processing Record 15 of Set 6 | the valley
# Processing Record 16 of Set 6 | mahebourg
# Processing Record 17 of Set 6 | cabedelo
# Processing Record 18 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 6 | namibe
# Processing Record 20 of Set 6 | ossora
# Processing Record 21 of Set 6 | podgornoye
# Processing Record 22 of Set 6 | plouzane
# Processing Record 23 of Set 6 | nagar karnul
# Processing Record 24 of Set 6 | ha giang
# Processing Record 25 of Set 6 | storforshei
# Processing Record 26 of Set 6 | qaanaaq
# Processing Record 27 of Set 6 | sovetskiy
# Processing Record 28 of Set 6 | gladstone
# Processing Record 29 of Set 6 | wittlich
# Processing Record 30 of Set 6 | hervey bay
# Processing Record 31 of Set 6 | chicama
# Processing Record 32 of Set 6 | virginia beach
# Processing Record 33 of Set 6 | shintomi
# Processing Record 34 of Set 6 | itoman
# Processing Record 35 of Set 6 | mudu
# Processing Record 36 of Set 6 | saint george
# Processing Record 37 of Set 6 | cidreira
# Processing Record 38 of Set 6 | bethel
# Processing Record 39 of Set 6 | hasaki
# Processing Record 40 of Set 6 | sambava
# Processing Record 41 of Set 6 | vestmanna
# Processing Record 42 of Set 6 | xam nua
# Processing Record 43 of Set 6 | anchorage
# Processing Record 44 of Set 6 | dzilam gonzalez
# Processing Record 45 of Set 6 | bintulu
# Processing Record 46 of Set 6 | bubaque
# Processing Record 47 of Set 6 | kuminskiy
# Processing Record 48 of Set 6 | gari
# Processing Record 49 of Set 6 | berbera
# Processing Record 50 of Set 6 | jurbarkas
# Processing Record 1 of Set 7 | jiaojiang
# Processing Record 2 of Set 7 | college
# Processing Record 3 of Set 7 | port augusta
# Processing Record 4 of Set 7 | lebu
# Processing Record 5 of Set 7 | ucluelet
# Processing Record 6 of Set 7 | lamia
# Processing Record 7 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 8 of Set 7 | iuna
# Processing Record 9 of Set 7 | vitim
# Processing Record 10 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 7 | saint-georges
# Processing Record 12 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 7 | portland
# Processing Record 14 of Set 7 | katobu
# Processing Record 15 of Set 7 | viedma
# Processing Record 16 of Set 7 | muros
# Processing Record 17 of Set 7 | boyuibe
# Processing Record 18 of Set 7 | camacupa
# Processing Record 19 of Set 7 | saint-pascal
# City not found. Skipping...
# Processing Record 20 of Set 7 | saint-pierre
# Processing Record 21 of Set 7 | paamiut
# Processing Record 22 of Set 7 | nanga eboko
# Processing Record 23 of Set 7 | imbituba
# Processing Record 24 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 25 of Set 7 | norsup
# Processing Record 26 of Set 7 | bengkalis
# City not found. Skipping...
# Processing Record 27 of Set 7 | cockburn town
# Processing Record 28 of Set 7 | kollam
# Processing Record 29 of Set 7 | tweed
# Processing Record 30 of Set 7 | torbay
# Processing Record 31 of Set 7 | terme
# Processing Record 32 of Set 7 | meulaboh
# Processing Record 33 of Set 7 | kokopo
# Processing Record 34 of Set 7 | kontagora
# Processing Record 35 of Set 7 | margate
# Processing Record 36 of Set 7 | isangel
# Processing Record 37 of Set 7 | qujing
# Processing Record 38 of Set 7 | goba
# Processing Record 39 of Set 7 | sechura
# Processing Record 40 of Set 7 | jalu
# Processing Record 41 of Set 7 | dargaville
# Processing Record 42 of Set 7 | yarada
# Processing Record 43 of Set 7 | beisfjord
# Processing Record 44 of Set 7 | kibala
# Processing Record 45 of Set 7 | gogrial
# Processing Record 46 of Set 7 | ixtapa
# Processing Record 47 of Set 7 | touros
# Processing Record 48 of Set 7 | ostrovnoy
# Processing Record 49 of Set 7 | port blair
# Processing Record 50 of Set 7 | sorland
# Processing Record 1 of Set 8 | grand-santi
# Processing Record 2 of Set 8 | fairbanks
# Processing Record 3 of Set 8 | ilorin
# Processing Record 4 of Set 8 | la ronge
# Processing Record 5 of Set 8 | lagos
# Processing Record 6 of Set 8 | lagoa
# Processing Record 7 of Set 8 | kahului
# Processing Record 8 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 8 | skjervoy
# Processing Record 10 of Set 8 | saskylakh
# Processing Record 11 of Set 8 | arak
# Processing Record 12 of Set 8 | hantsport
# Processing Record 13 of Set 8 | mentougou
# Processing Record 14 of Set 8 | pangnirtung
# Processing Record 15 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 8 | naze
# Processing Record 17 of Set 8 | medicine hat
# Processing Record 18 of Set 8 | guerrero negro
# Processing Record 19 of Set 8 | olafsvik
# Processing Record 20 of Set 8 | sitka
# Processing Record 21 of Set 8 | mishan
# Processing Record 22 of Set 8 | magole
# Processing Record 23 of Set 8 | praia da vitoria
# Processing Record 24 of Set 8 | yidu
# Processing Record 25 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 8 | raga
# Processing Record 27 of Set 8 | ust-tsilma
# Processing Record 28 of Set 8 | brownsville
# Processing Record 29 of Set 8 | cradock
# Processing Record 30 of Set 8 | yar-sale
# Processing Record 31 of Set 8 | senno
# Processing Record 32 of Set 8 | gualeguay
# Processing Record 33 of Set 8 | belmonte
# Processing Record 34 of Set 8 | henties bay
# Processing Record 35 of Set 8 | vila
# Processing Record 36 of Set 8 | santa cruz de la palma
# Processing Record 37 of Set 8 | ayan
# Processing Record 38 of Set 8 | cambrils
# Processing Record 39 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 8 | arkhipo-osipovka
# Processing Record 41 of Set 8 | yeppoon
# Processing Record 42 of Set 8 | grand forks
# Processing Record 43 of Set 8 | tautira
# Processing Record 44 of Set 8 | eyl
# Processing Record 45 of Set 8 | sandy bay
# Processing Record 46 of Set 8 | acapulco
# Processing Record 47 of Set 8 | tecoanapa
# Processing Record 48 of Set 8 | newport
# Processing Record 49 of Set 8 | kloulklubed
# Processing Record 50 of Set 8 | sandwick
# Processing Record 1 of Set 9 | saint-joseph
# Processing Record 2 of Set 9 | noumea
# Processing Record 3 of Set 9 | aasiaat
# Processing Record 4 of Set 9 | moron
# Processing Record 5 of Set 9 | novovarshavka
# Processing Record 6 of Set 9 | araouane
# Processing Record 7 of Set 9 | sao jose da coroa grande
# Processing Record 8 of Set 9 | beaupre
# Processing Record 9 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 10 of Set 9 | birjand
# Processing Record 11 of Set 9 | katha
# City not found. Skipping...
# Processing Record 12 of Set 9 | taksimo
# Processing Record 13 of Set 9 | fortuna
# Processing Record 14 of Set 9 | aksu
# Processing Record 15 of Set 9 | tlaltenango
# Processing Record 16 of Set 9 | batagay-alyta
# Processing Record 17 of Set 9 | yerbogachen
# Processing Record 18 of Set 9 | aleksandrov gay
# Processing Record 19 of Set 9 | tawau
# Processing Record 20 of Set 9 | surskoye
# Processing Record 21 of Set 9 | burica
# City not found. Skipping...
# Processing Record 22 of Set 9 | nyurba
# Processing Record 23 of Set 9 | umm lajj
# Processing Record 24 of Set 9 | mount gambier
# Processing Record 25 of Set 9 | izumo
# Processing Record 26 of Set 9 | niquero
# Processing Record 27 of Set 9 | tyup
# Processing Record 28 of Set 9 | carauari
# Processing Record 29 of Set 9 | santa maria
# Processing Record 30 of Set 9 | norman wells
# Processing Record 31 of Set 9 | tete
# Processing Record 32 of Set 9 | tezu
# Processing Record 33 of Set 9 | ladario
# Processing Record 34 of Set 9 | el tocuyo
# Processing Record 35 of Set 9 | matagami
# Processing Record 36 of Set 9 | beyneu
# Processing Record 37 of Set 9 | taoudenni
# Processing Record 38 of Set 9 | lucapa
# Processing Record 39 of Set 9 | dukat
# Processing Record 40 of Set 9 | lake city
# Processing Record 41 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 9 | mindelo
# Processing Record 43 of Set 9 | shimsk
# Processing Record 44 of Set 9 | thunder bay
# Processing Record 45 of Set 9 | port-cartier
# Processing Record 46 of Set 9 | coquimbo
# Processing Record 47 of Set 9 | sao felix do xingu
# Processing Record 48 of Set 9 | kargasok
# Processing Record 49 of Set 9 | puerto escondido
# Processing Record 50 of Set 9 | norden
# Processing Record 1 of Set 10 | kharhial
# Processing Record 2 of Set 10 | esperance
# Processing Record 3 of Set 10 | caravelas
# Processing Record 4 of Set 10 | tilichiki
# Processing Record 5 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 10 | pangody
# Processing Record 7 of Set 10 | zyryanka
# Processing Record 8 of Set 10 | orzinuovi
# Processing Record 9 of Set 10 | tiksi
# Processing Record 10 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 11 of Set 10 | razvilnoye
# Processing Record 12 of Set 10 | hamina
# Processing Record 13 of Set 10 | gubkinskiy
# Processing Record 14 of Set 10 | vao
# Processing Record 15 of Set 10 | lensk
# Processing Record 16 of Set 10 | lorengau
# Processing Record 17 of Set 10 | madarounfa
# Processing Record 18 of Set 10 | kirakira
# Processing Record 19 of Set 10 | barbastro
# Processing Record 20 of Set 10 | caohai
# Processing Record 21 of Set 10 | karaton
# Processing Record 22 of Set 10 | gat
# Processing Record 23 of Set 10 | preobrazheniye
# Processing Record 24 of Set 10 | ornskoldsvik
# Processing Record 25 of Set 10 | bambanglipuro
# Processing Record 26 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 10 | sao joao da barra
# Processing Record 28 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 29 of Set 10 | geraldton
# Processing Record 30 of Set 10 | sioux lookout
# Processing Record 31 of Set 10 | erenhot
# Processing Record 32 of Set 10 | pacific grove
# Processing Record 33 of Set 10 | owando
# Processing Record 34 of Set 10 | candido de abreu
# Processing Record 35 of Set 10 | maniitsoq
# Processing Record 36 of Set 10 | colares
# Processing Record 37 of Set 10 | natchez
# Processing Record 38 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 10 | zhigansk
# Processing Record 40 of Set 10 | champerico
# Processing Record 41 of Set 10 | san juan
# Processing Record 42 of Set 10 | cairns
# Processing Record 43 of Set 10 | christchurch
# Processing Record 44 of Set 10 | save
# Processing Record 45 of Set 10 | sterling
# Processing Record 46 of Set 10 | samagaltay
# Processing Record 47 of Set 10 | bathsheba
# Processing Record 48 of Set 10 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 49 of Set 10 | liverpool
# Processing Record 50 of Set 10 | nangong
# Processing Record 1 of Set 11 | saint anthony
# Processing Record 2 of Set 11 | smithers
# Processing Record 3 of Set 11 | mehamn
# Processing Record 4 of Set 11 | deputatskiy
# Processing Record 5 of Set 11 | kununurra
# Processing Record 6 of Set 11 | ipu
# Processing Record 7 of Set 11 | jimo
# Processing Record 8 of Set 11 | eskisehir
# Processing Record 9 of Set 11 | hambantota
# Processing Record 10 of Set 11 | kuytun
# Processing Record 11 of Set 11 | shahrud
# Processing Record 12 of Set 11 | parczew
# Processing Record 13 of Set 11 | port lincoln
# Processing Record 14 of Set 11 | dicabisagan
# Processing Record 15 of Set 11 | broome
# Processing Record 16 of Set 11 | high level
# Processing Record 17 of Set 11 | forst
# Processing Record 18 of Set 11 | kodiak
# Processing Record 19 of Set 11 | itacare
# Processing Record 20 of Set 11 | labis
# Processing Record 21 of Set 11 | alekseyevka
# Processing Record 22 of Set 11 | millinocket
# Processing Record 23 of Set 11 | tomatlan
# Processing Record 24 of Set 11 | benghazi
# Processing Record 25 of Set 11 | charagua
# Processing Record 26 of Set 11 | santeramo in colle
# Processing Record 27 of Set 11 | salalah
# Processing Record 28 of Set 11 | pokrovka
# Processing Record 29 of Set 11 | sorso
# Processing Record 30 of Set 11 | fengcheng
# Processing Record 31 of Set 11 | kieta
# Processing Record 32 of Set 11 | vegreville
# Processing Record 33 of Set 11 | nelson bay
# Processing Record 34 of Set 11 | kendari
# Processing Record 35 of Set 11 | huejuquilla el alto
# Processing Record 36 of Set 11 | susanville
# Processing Record 37 of Set 11 | iquitos
# Processing Record 38 of Set 11 | rantepao
# Processing Record 39 of Set 11 | kerrville
# Processing Record 40 of Set 11 | dillon
# Processing Record 41 of Set 11 | altay
# Processing Record 42 of Set 11 | kerchevskiy
# Processing Record 43 of Set 11 | riyadh
# Processing Record 44 of Set 11 | ust-nera
# Processing Record 45 of Set 11 | luanda
# Processing Record 46 of Set 11 | altamira
# Processing Record 47 of Set 11 | mackay
# Processing Record 48 of Set 11 | lucenec
# Processing Record 49 of Set 11 | malaya purga
# Processing Record 50 of Set 11 | leshukonskoye
# Processing Record 1 of Set 12 | urucara
# Processing Record 2 of Set 12 | qasigiannguit
# Processing Record 3 of Set 12 | tartus
# Processing Record 4 of Set 12 | treinta y tres
# Processing Record 5 of Set 12 | sanandaj
# Processing Record 6 of Set 12 | shitanjing
# Processing Record 7 of Set 12 | natal
# Processing Record 8 of Set 12 | bauchi
# Processing Record 9 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 10 of Set 12 | yinchuan
# Processing Record 11 of Set 12 | lata
# Processing Record 12 of Set 12 | grand gaube
# Processing Record 13 of Set 12 | talas
# Processing Record 14 of Set 12 | makokou
# Processing Record 15 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 16 of Set 12 | tongren
# Processing Record 17 of Set 12 | haines junction
# Processing Record 18 of Set 12 | kandiari
# Processing Record 19 of Set 12 | ilebo
# Processing Record 20 of Set 12 | neuquen
# Processing Record 21 of Set 12 | ati
# Processing Record 22 of Set 12 | takaungu
# Processing Record 23 of Set 12 | puga
# Processing Record 24 of Set 12 | balikpapan
# Processing Record 25 of Set 12 | gorontalo
# Processing Record 26 of Set 12 | tanout
# Processing Record 27 of Set 12 | kelvington
# Processing Record 28 of Set 12 | aykhal
# Processing Record 29 of Set 12 | ayr
# Processing Record 30 of Set 12 | uyemskiy
# Processing Record 31 of Set 12 | kamnik
# Processing Record 32 of Set 12 | chokwe
# Processing Record 33 of Set 12 | padang
# Processing Record 34 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 12 | whitehorse
# Processing Record 36 of Set 12 | boden
# Processing Record 37 of Set 12 | sept-iles
# Processing Record 38 of Set 12 | ritchie
# Processing Record 39 of Set 12 | biloela
# Processing Record 40 of Set 12 | mount pleasant
# Processing Record 41 of Set 12 | tiznit
# Processing Record 42 of Set 12 | bayji
# Processing Record 43 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 12 | omboue
# Processing Record 45 of Set 12 | mandurah
# Processing Record 46 of Set 12 | ukiah
# Processing Record 47 of Set 12 | labrea
# Processing Record 48 of Set 12 | bibiani
# Processing Record 49 of Set 12 | xichang
# Processing Record 50 of Set 12 | maceio
# Processing Record 1 of Set 13 | wollongong
# Processing Record 2 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 3 of Set 13 | gisborne
# Processing Record 4 of Set 13 | linqing
# Processing Record 5 of Set 13 | tayu
# Processing Record 6 of Set 13 | tiarei
# Processing Record 7 of Set 13 | nouadhibou
# Processing Record 8 of Set 13 | san quintin
# Processing Record 9 of Set 13 | eltham
# Processing Record 10 of Set 13 | strai
# Processing Record 11 of Set 13 | gigmoto
# Processing Record 12 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 13 | khandyga
# Processing Record 14 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 15 of Set 13 | forth
# Processing Record 16 of Set 13 | pisco
# Processing Record 17 of Set 13 | llanes
# Processing Record 18 of Set 13 | sompeta
# Processing Record 19 of Set 13 | nantucket
# Processing Record 20 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 13 | tazovskiy
# Processing Record 22 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 13 | twentynine palms
# Processing Record 24 of Set 13 | trofors
# Processing Record 25 of Set 13 | sola
# Processing Record 26 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 13 | abu dhabi
# Processing Record 28 of Set 13 | pemba
# Processing Record 29 of Set 13 | balclutha
# Processing Record 30 of Set 13 | solnechnyy
# Processing Record 31 of Set 13 | nouakchott
# Processing Record 32 of Set 13 | varanasi
# Processing Record 33 of Set 13 | slave lake
# Processing Record 34 of Set 13 | dodge city
# Processing Record 35 of Set 13 | zaragoza
# Processing Record 36 of Set 13 | hofn
# Processing Record 37 of Set 13 | barcelos
# Processing Record 38 of Set 13 | mahanoro
# Processing Record 39 of Set 13 | nam tha
# City not found. Skipping...
# Processing Record 40 of Set 13 | shahr-e babak
# Processing Record 41 of Set 13 | ahipara
# Processing Record 42 of Set 13 | samarai
# Processing Record 43 of Set 13 | nsanje
# Processing Record 44 of Set 13 | zhob
# Processing Record 45 of Set 13 | ariquemes
# Processing Record 46 of Set 13 | cotonou
# Processing Record 47 of Set 13 | carlsbad
# Processing Record 48 of Set 13 | stornoway
# Processing Record 49 of Set 13 | mayumba
# Processing Record 50 of Set 13 | yurginskoye
# Processing Record 1 of Set 14 | andapa
# Processing Record 2 of Set 14 | alofi
# Processing Record 3 of Set 14 | kazanskoye
# Processing Record 4 of Set 14 | dzhebariki-khaya
# Processing Record 5 of Set 14 | saint-raymond
# Processing Record 6 of Set 14 | chunskiy
# Processing Record 7 of Set 14 | benxi
# Processing Record 8 of Set 14 | bairiki
# Processing Record 9 of Set 14 | harlingen
# Processing Record 10 of Set 14 | san rafael
# Processing Record 11 of Set 14 | kropotkin
# Processing Record 12 of Set 14 | ufa
# Processing Record 13 of Set 14 | fayetteville
# Processing Record 14 of Set 14 | maldonado
# Processing Record 15 of Set 14 | sisimiut
# Processing Record 16 of Set 14 | marsaxlokk
# Processing Record 17 of Set 14 | vyazma
# Processing Record 18 of Set 14 | cassilandia
# Processing Record 19 of Set 14 | mayo
# Processing Record 20 of Set 14 | vyazemskiy
# Processing Record 21 of Set 14 | naantali
# Processing Record 22 of Set 14 | puerto baquerizo moreno
# Processing Record 23 of Set 14 | gainesville
# Processing Record 24 of Set 14 | josefina
# Processing Record 25 of Set 14 | itarema
# Processing Record 26 of Set 14 | kattivakkam
# Processing Record 27 of Set 14 | pierre
# Processing Record 28 of Set 14 | felipe carrillo puerto
# Processing Record 29 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 14 | sampit
# Processing Record 31 of Set 14 | khandbari
# Processing Record 32 of Set 14 | tukrah
# Processing Record 33 of Set 14 | ust-karsk
# Processing Record 34 of Set 14 | rovaniemi
# Processing Record 35 of Set 14 | luganville
# Processing Record 36 of Set 14 | barreirinha
# Processing Record 37 of Set 14 | gushikawa
# Processing Record 38 of Set 14 | bulancak
# Processing Record 39 of Set 14 | bilibino
# Processing Record 40 of Set 14 | maragogi
# Processing Record 41 of Set 14 | ouadda
# Processing Record 42 of Set 14 | merrill
# Processing Record 43 of Set 14 | chiredzi
# Processing Record 44 of Set 14 | avera
# Processing Record 45 of Set 14 | tahe
# Processing Record 46 of Set 14 | khomutovo
# Processing Record 47 of Set 14 | te anau
# Processing Record 48 of Set 14 | provost
# Processing Record 49 of Set 14 | tena
# Processing Record 50 of Set 14 | pryazha
# Processing Record 1 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 2 of Set 15 | craig
# Processing Record 3 of Set 15 | charters towers
# Processing Record 4 of Set 15 | sabang
# Processing Record 5 of Set 15 | goderich
# Processing Record 6 of Set 15 | san angelo
# Processing Record 7 of Set 15 | turukhansk
# Processing Record 8 of Set 15 | kaeo
# Processing Record 9 of Set 15 | yingshang
# City not found. Skipping...
# Processing Record 10 of Set 15 | faya
# Processing Record 11 of Set 15 | paranaiba
# Processing Record 12 of Set 15 | kijang
# Processing Record 13 of Set 15 | hvide sande
# Processing Record 14 of Set 15 | jutai
# Processing Record 15 of Set 15 | chernyshevsk
# Processing Record 16 of Set 15 | praya
# Processing Record 17 of Set 15 | boyolangu
# Processing Record 18 of Set 15 | tagdangua
# City not found. Skipping...
# Processing Record 19 of Set 15 | matadi
# Processing Record 20 of Set 15 | matameye
# City not found. Skipping...
# Processing Record 21 of Set 15 | hornepayne
# Processing Record 22 of Set 15 | victoria point
# Processing Record 23 of Set 15 | makakilo city
# Processing Record 24 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 15 | aras
# Processing Record 26 of Set 15 | sibolga
# Processing Record 27 of Set 15 | mahon
# Processing Record 28 of Set 15 | qinhuangdao
# Processing Record 29 of Set 15 | palafrugell
# Processing Record 30 of Set 15 | channel-port aux basques
# Processing Record 31 of Set 15 | san cristobal
# Processing Record 32 of Set 15 | lincoln
# Processing Record 33 of Set 15 | atar
# Processing Record 34 of Set 15 | tombouctou
# Processing Record 35 of Set 15 | amapa
# Processing Record 36 of Set 15 | lively
# Processing Record 37 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 15 | okato
# Processing Record 39 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 15 | houma
# Processing Record 41 of Set 15 | vila franca do campo
# Processing Record 42 of Set 15 | cap malheureux
# Processing Record 43 of Set 15 | autazes
# Processing Record 44 of Set 15 | berasia
# Processing Record 45 of Set 15 | marevo
# Processing Record 46 of Set 15 | ostuacan
# Processing Record 47 of Set 15 | chapais
# Processing Record 48 of Set 15 | vila do maio
# Processing Record 49 of Set 15 | changqing
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Longyearbyen  78.2186   15.6401     40.84        93          75
# 1          Hobart -42.8794  147.3294     56.26        58          75
# 2        Hermanus -34.4187   19.2345     55.80        85           2
# 3           Airai  -8.9266  125.4092     73.98        64          37
# 4        Thompson  55.7435  -97.8558     41.16        75           0
# 5  Saint-Philippe -21.3585   55.7679     74.79        81          63
# 6    Ponta Do Sol  32.6667  -17.1000     70.43        82          21
# 7           Chara  56.9064  118.2631     32.58        73          64
# 8           Gayny  60.3071   54.3241     29.89        68          97
# 9       Belyy Yar  53.6039   91.3903     37.29        56           0
#
#    Wind Speed Country Current Description
# 0        5.75      SJ       broken clouds
# 1        8.05      AU       broken clouds
# 2        4.97      ZA           clear sky
# 3        0.94      TL    scattered clouds
# 4       10.36      CA           clear sky
# 5       13.15      RE          light rain
# 6        6.22      PT          few clouds
# 7        1.99      RU       broken clouds
# 8        9.46      RU     overcast clouds
# 9        4.47      RU           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ["City","Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Longyearbyen      SJ  78.2186   15.6401     40.84        93          75
# 1          Hobart      AU -42.8794  147.3294     56.26        58          75
# 2        Hermanus      ZA -34.4187   19.2345     55.80        85           2
# 3           Airai      TL  -8.9266  125.4092     73.98        64          37
# 4        Thompson      CA  55.7435  -97.8558     41.16        75           0
# ..            ...     ...      ...       ...       ...       ...         ...
# 681        Marevo      RU  57.3146   32.0804     46.67        94          92
# 682      Ostuacan      MX  17.4167  -93.3000     67.64        89          95
# 683       Chapais      CA  49.7834  -74.8492     40.78        80          14
# 684  Vila Do Maio      CV  15.1333  -23.2167     79.59        80          81
# 685     Changqing      CN  36.5575  116.7272     85.66        37          23
#
#      Wind Speed Current Description
# 0          5.75       broken clouds
# 1          8.05       broken clouds
# 2          4.97           clear sky
# 3          0.94    scattered clouds
# 4         10.36           clear sky
# ..          ...                 ...
# 681        5.82     overcast clouds
# 682        2.06     overcast clouds
# 683        8.48          few clouds
# 684        9.10       broken clouds
# 685       13.38          few clouds
#
# [686 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
